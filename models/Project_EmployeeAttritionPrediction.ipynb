# %% [markdown]
# ### **Project**

# %% [markdown]
# Submitted by: Mohammed Ihsan P, Aleena Francis, Rustham Shahan V, Alka Sherine Benny, Reuben M Sunil

# %% [markdown]
# **Domain**-**HR** **Analytics**

# %% [markdown]
# ### **1-Data Understanding and EDA-:**

# %% [markdown]
# **Dataset Description:**
#
# ID- Employee ID
#
# Name- Employee Name
#
# Department- Department
#
# GEO- Geographical location
#
# Role- Current Role or title of employee
#
# Rising Star- Indicates the level of promise or promote-ability the employee has. Scale(1-5)
#
# Will_Relocate- Is the employee willing to relocate? 0- No, 1- Yes
#
# Critical- Is the employee critical to the organization? 0- No, 1- Yes
#
# Trending Perf- How is the employee trending in performance this year? Scale (1-10)
#
# Talent_Level- This field represents a subjective level of management's view of the employee. Scale (1-10)
#
# Validated_Talent_Level-This field represents senior managements view of what the manager stated.
#
# Percent_Remote- The percentage of the employee's work that is done remotely.
#
# EMP_Sat_OnPrem - One indicator from a survey that was sent to employees. It indicates the employee's satisfaction of work on the corporation’s physical work locations. Scale (1-10)
#
# EMP_Sat_Remote - One indicator from a survey that was sent to employees. It means that the employee's satisfaction of work away from the corporation’s physical work locations. Scale (1-10)
#
# EMP_Engagement - One indicator from a survey that was sent to employees. Engagement represents the employee's feeling about how they feel about being engaged in company activities. Scale(1-5)
#
# last_evaluation- The score on the last employee evaluation.Scale (1-10)
#
# number_project- The number of projects the employee works on throughout the year.
#
# average_montly_hours- The average number of hours the employee works monthly.
#
# time_spend_company- Years of service
#
# Work_accident - The number of accidents the employee is involved in.
#
# left_Company- Did the employee leave the company? 0- No, 1- Yes
#
# CSR Factor - Corporate Social Responsibility of employees.
#
# promotion_last_5years-Did the employee get promoted in last 5 years? 0- No, 1- Yes
#
# salary- Relative pay grade (low, medium, high) by role.
#
# Gender- M or F
#
# LinkedIn_Hits - The number of times employee visits LinkedIn networking sites.
#
# Emp_Work_Status - One indicator from a survey that was sent to employees. Status represents how strongly employee feels about their status level in the organization. Scale (1-10)
#
# Emp_Identity- How the employee identifies themselves with the company. Scale (1-10)
#
# Emp_Role- How the employee identifies themselves with the importance of their role in the company. Scale (1-10)
#
# Emp_Position- How the employee identifies themselves with the importance of their position in the company. Scale (1-10)
#
# Emp_Title- How the employee feels about their title.Scale (1-10)
#
# Women_Leave - Women who left the company.
#
# Men_Leave - Men who left the company.
#
# Emp_Competitive - One indicator from a survey that was sent to employees. How employee feels about the competitive nature of work in the organization. Scale (1-10)
#
# Emp_Collaborative- One indicator from a survey that was sent to employees. How employee feels about the collaborative nature of work in the organization.Scale (1-10)
#
# Sensor_StepCount - Sentient devices are used to capture certain employee activities. In this case number of steps.
#
# Sensor_Heartbeat(Average/Min) - Sentient devices are used to capture certain employee activities. In this case heartbeat.
#
# Sensor_Proximity(1-highest/10-lowest) - Sentient devices are used to capture certain employee activities. In this case how close they are to their company laptop.

# %%
#import libraries
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('/content/HR_Engagement_Sat_Sales.csv')

# %%
pd.set_option('display.max_columns', 500)
data.head()
# Out:
#    ID      Name       Department     GEO             Role  Rising_Star  \
# 0   1    BRADDY       Operations      US               VP          NaN
# 1   2     BORST            Sales      UK  Senior Director          NaN
# 2   3  BIRDWELL          Finance  France  Senior Director          NaN
# 3   4      BENT  Human Resources   China  Senior Director          NaN
# 4   5     BAZAN               IT   Korea         Director          NaN
#
#    Will_Relocate  Critical  Trending Perf  Talent_Level  \
# 0              0       1.0              3             6
# 1              0       NaN              3             6
# 2              0       NaN              3             6
# 3              0       NaN              3             6
# 4              0       NaN              3             6
#
#    Validated_Talent_Level  Percent_Remote  EMP_Sat_OnPrem_1  EMP_Sat_OnPrem_2  \
# 0                       6             0.4               3.0               3.0
# 1                       6             0.4               3.0               3.0
# 2                       6             0.4               3.0               3.0
# 3                       6             0.4               3.0               3.0
# 4                       6             0.4               3.0               3.0
#
#    EMP_Sat_OnPrem_3  EMP_Sat_OnPrem_4  EMP_Sat_OnPrem_5  EMP_Sat_Remote_1  \
# 0               4.0               3.0               5.0                 2
# 1               4.0               3.0               5.0                 2
# 2               4.0               3.0               5.0                 2
# 3               4.0               3.0               5.0                 2
# 4               4.0               3.0               5.0                 2
#
#    EMP_Sat_Remote_2  EMP_Sat_Remote_3  EMP_Sat_Remote_4  EMP_Sat_Remote_5  \
# 0                 3                 2                 3                 2
# 1                 3                 2                 3                 2
# 2                 3                 2                 3                 2
# 3                 3                 2                 3                 2
# 4                 3                 2                 3                 2
#
#    EMP_Engagement_1  EMP_Engagement_2  EMP_Engagement_3  EMP_Engagement_4  \
# 0                 5                 5                 4                 4
# 1                 5                 5                 4                 4
# 2                 5                 5                 4                 4
# 3                 5                 5                 4                 4
# 4                 5                 5                 4                 4
#
#    EMP_Engagement_5  last_evaluation  number_project  average_montly_hours  \
# 0                 3             0.36               3                   168
# 1                 3             0.36               5                   159
# 2                 3             0.36               2                   282
# 3                 3             0.36               4                   278
# 4                 3             0.36               6                   256
#
#    time_spend_company  Work_accident  left_Company  CSR Factor  \
# 0                   3              1             0         NaN
# 1                   2              0             0         NaN
# 2                   3              0             0         NaN
# 3                   4              1             0         NaN
# 4                   5              0             0         NaN
#
#    promotion_last_5years        sales  salary Gender  LinkedIn_Hits  \
# 0                      0        sales     low      M              5
# 1                      0   accounting     low      F             58
# 2                      0  product_mng  medium      F             42
# 3                      0  product_mng    high      M             37
# 4                      0        sales     low      F              6
#
#    Emp_Work_Status2  Emp_Work_Status_3  Emp_Work_Status_4  Emp_Work_Status_5  \
# 0                 4                  3                  1                  1
# 1                 3                  3                  4                  3
# 2                 2                  4                  1                  3
# 3                 3                  1                  4                  5
# 4                 4                  5                  4                  5
#
#    Emp_Identity  Emp_Role  Emp_Position  Emp_Title  Women_Leave  Men_Leave  \
# 0             1         1             2          1          NaN        1.0
# 1             2         1             2          1          0.0        NaN
# 2             1         1             2          2          1.0        NaN
# 3             2         1             2          1          NaN        1.0
# 4             1         1             2          1          1.0        NaN
#
#    Emp_Competitive_1  Emp_Competitive_2  Emp_Competitive_3  Emp_Competitive_4  \
# 0                  2                  4                  2                  2
# 1                  2                  2                  1                  4
# 2                  1                  5                  1                  2
# 3                  1                  1                  2                  5
# 4                  1                  4                  1                  5
#
#    Emp_Competitive_5  Emp_Collaborative_1  Emp_Collaborative_2  \
# 0                  2                    2                    2
# 1                  1                    3                    2
# 2                  5                    2                    2
# 3                  1                    1                    2
# 4                  3                    5                    1
#
#    Emp_Collaborative_3  Emp_Collaborative_4  Emp_Collaborative_5  \
# 0                    2                    1                    5
# 1                    5                    1                    5
# 2                    4                    4                    4
# 3                    4                    4                    1
# 4                    2                    5                    4
#
#    Sensor_StepCount  Sensor_Heartbeat(Average/Min)  \
# 0              1841                             61
# 1              1990                             90
# 2              3193                             80
# 3              3248                             77
# 4              3149                             80
#
#    Sensor_Proximity(1-highest/10-lowest)
# 0                                      9
# 1                                      8
# 2                                      8
# 3                                      6
# 4                                     10

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 62 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   ID                                     14999 non-null  int64
#  1   Name                                   14997 non-null  object
#  2   Department                             14999 non-null  object
#  3   GEO                                    14999 non-null  object
#  4   Role                                   14999 non-null  object
#  5   Rising_Star                            21 non-null     float64
#  6   Will_Relocate                          14999 non-null  int64
#  7   Critical                               480 non-null    float64
#  8   Trending Perf                          14999 non-null  int64
#  9   Talent_Level                           14999 non-null  int64
#  10  Validated_Talent_Level                 14999 non-null  int64
#  11  Percent_Remote                         14999 non-null  float64
#  12  EMP_Sat_OnPrem_1                       14871 non-null  float64
#  13  EMP_Sat_OnPrem_2                       14871 non-null  float64
#  14  EMP_Sat_OnPrem_3                       14871 non-null  float64
#  15  EMP_Sat_OnPrem_4                       14871 non-null  float64
#  16  EMP_Sat_OnPrem_5                       14871 non-null  float64
#  17  EMP_Sat_Remote_1                       14999 non-null  int64
#  18  EMP_Sat_Remote_2                       14999 non-null  int64
#  19  EMP_Sat_Remote_3                       14999 non-null  int64
#  20  EMP_Sat_Remote_4                       14999 non-null  int64
#  21  EMP_Sat_Remote_5                       14999 non-null  int64
#  22  EMP_Engagement_1                       14999 non-null  int64
#  23  EMP_Engagement_2                       14999 non-null  int64
#  24  EMP_Engagement_3                       14999 non-null  int64
#  25  EMP_Engagement_4                       14999 non-null  int64
#  26  EMP_Engagement_5                       14999 non-null  int64
#  27  last_evaluation                        14999 non-null  float64
#  28  number_project                         14999 non-null  int64
#  29  average_montly_hours                   14999 non-null  int64
#  30  time_spend_company                     14999 non-null  int64
#  31  Work_accident                          14999 non-null  int64
#  32  left_Company                           14999 non-null  int64
#  33  CSR Factor                             1713 non-null   float64
#  34  promotion_last_5years                  14999 non-null  int64
#  35  sales                                  14999 non-null  object
#  36  salary                                 14999 non-null  object
#  37  Gender                                 14999 non-null  object
#  38  LinkedIn_Hits                          14999 non-null  int64
#  39  Emp_Work_Status2                       14999 non-null  int64
#  40  Emp_Work_Status_3                      14999 non-null  int64
#  41  Emp_Work_Status_4                      14999 non-null  int64
#  42  Emp_Work_Status_5                      14999 non-null  int64
#  43  Emp_Identity                           14999 non-null  int64
#  44  Emp_Role                               14999 non-null  int64
#  45  Emp_Position                           14999 non-null  int64
#  46  Emp_Title                              14999 non-null  int64
#  47  Women_Leave                            7596 non-null   float64
#  48  Men_Leave                              4865 non-null   float64
#  49  Emp_Competitive_1                      14999 non-null  int64
#  50  Emp_Competitive_2                      14999 non-null  int64
#  51  Emp_Competitive_3                      14999 non-null  int64
#  52  Emp_Competitive_4                      14999 non-null  int64
#  53  Emp_Competitive_5                      14999 non-null  int64
#  54  Emp_Collaborative_1                    14999 non-null  int64
#  55  Emp_Collaborative_2                    14999 non-null  int64
#  56  Emp_Collaborative_3                    14999 non-null  int64
#  57  Emp_Collaborative_4                    14999 non-null  int64
#  58  Emp_Collaborative_5                    14999 non-null  int64
#  59  Sensor_StepCount                       14999 non-null  int64
#  60  Sensor_Heartbeat(Average/Min)          14999 non-null  int64
#  61  Sensor_Proximity(1-highest/10-lowest)  14999 non-null  int64
# dtypes: float64(12), int64(43), object(7)
# memory usage: 7.1+ MB

# %%
data.shape
# Out:
# (14999, 62)

# %% [markdown]
# Our dataset contains 14999 rows and 62 columns.

# %%
data.describe(include='all')
# Out:
#                   ID    Name  Department    GEO       Role  Rising_Star  \
# count   14999.000000   14997       14999  14999      14999         21.0
# unique           NaN   14997           6      9          7          NaN
# top              NaN  BRADDY  Operations     UK  Level 2-4          NaN
# freq             NaN       1        2500   1772       6889          NaN
# mean     7500.000000     NaN         NaN    NaN        NaN          1.0
# std      4329.982679     NaN         NaN    NaN        NaN          0.0
# min         1.000000     NaN         NaN    NaN        NaN          1.0
# 25%      3750.500000     NaN         NaN    NaN        NaN          1.0
# 50%      7500.000000     NaN         NaN    NaN        NaN          1.0
# 75%     11249.500000     NaN         NaN    NaN        NaN          1.0
# max     14999.000000     NaN         NaN    NaN        NaN          1.0
#
#         Will_Relocate  Critical  Trending Perf  Talent_Level  \
# count    14999.000000     480.0        14999.0       14999.0
# unique            NaN       NaN            NaN           NaN
# top               NaN       NaN            NaN           NaN
# freq              NaN       NaN            NaN           NaN
# mean         0.499833       1.0            3.0           6.0
# std          0.500017       0.0            0.0           0.0
# min          0.000000       1.0            3.0           6.0
# 25%          0.000000       1.0            3.0           6.0
# 50%          0.000000       1.0            3.0           6.0
# 75%          1.000000       1.0            3.0           6.0
# max          1.000000       1.0            3.0           6.0
#
#         Validated_Talent_Level  Percent_Remote  EMP_Sat_OnPrem_1  \
# count                  14999.0    14999.000000           14871.0
# unique                     NaN             NaN               NaN
# top                        NaN             NaN               NaN
# freq                       NaN             NaN               NaN
# mean                       6.0        0.617321               3.0
# std                        0.0        0.193841               0.0
# min                        6.0        0.400000               3.0
# 25%                        6.0        0.400000               3.0
# 50%                        6.0        0.800000               3.0
# 75%                        6.0        0.800000               3.0
# max                        6.0        1.000000               3.0
#
#         EMP_Sat_OnPrem_2  EMP_Sat_OnPrem_3  EMP_Sat_OnPrem_4  \
# count       14871.000000      14871.000000      14871.000000
# unique               NaN               NaN               NaN
# top                  NaN               NaN               NaN
# freq                 NaN               NaN               NaN
# mean            2.731962          3.731962          2.731962
# std             0.681369          0.681369          0.681369
# min             1.000000          2.000000          1.000000
# 25%             3.000000          4.000000          3.000000
# 50%             3.000000          4.000000          3.000000
# 75%             3.000000          4.000000          3.000000
# max             3.000000          4.000000          3.000000
#
#         EMP_Sat_OnPrem_5  EMP_Sat_Remote_1  EMP_Sat_Remote_2  \
# count       14871.000000      14999.000000      14999.000000
# unique               NaN               NaN               NaN
# top                  NaN               NaN               NaN
# freq                 NaN               NaN               NaN
# mean            3.943649          2.839723          4.367691
# std             1.244511          0.776054          0.929979
# min             1.000000          2.000000          3.000000
# 25%             4.000000          2.000000          3.000000
# 50%             4.000000          3.000000          5.000000
# 75%             5.000000          3.000000          5.000000
# max             5.000000          5.000000          5.000000
#
#         EMP_Sat_Remote_3  EMP_Sat_Remote_4  EMP_Sat_Remote_5  \
# count       14999.000000      14999.000000      14999.000000
# unique               NaN               NaN               NaN
# top                  NaN               NaN               NaN
# freq                 NaN               NaN               NaN
# mean            3.367691          3.761784          3.973598
# std             0.929979          0.580834          1.367462
# min             2.000000          3.000000          2.000000
# 25%             2.000000          3.000000          2.000000
# 50%             4.000000          4.000000          5.000000
# 75%             4.000000          4.000000          5.000000
# max             4.000000          5.000000          5.000000
#
#         EMP_Engagement_1  EMP_Engagement_2  EMP_Engagement_3  \
# count       14999.000000      14999.000000      14999.000000
# unique               NaN               NaN               NaN
# top                  NaN               NaN               NaN
# freq                 NaN               NaN               NaN
# mean            4.047670          4.285752          3.761917
# std             1.703696          1.277772          0.425924
# min             1.000000          2.000000          3.000000
# 25%             5.000000          5.000000          4.000000
# 50%             5.000000          5.000000          4.000000
# 75%             5.000000          5.000000          4.000000
# max             5.000000          5.000000          4.000000
#
#         EMP_Engagement_4  EMP_Engagement_5  last_evaluation  number_project  \
# count       14999.000000      14999.000000     14999.000000    14999.000000
# unique               NaN               NaN              NaN             NaN
# top                  NaN               NaN              NaN             NaN
# freq                 NaN               NaN              NaN             NaN
# mean            3.523835          2.523835         0.716102        3.803054
# std             0.851848          0.851848         0.171169        1.232592
# min             2.000000          1.000000         0.360000        2.000000
# 25%             4.000000          3.000000         0.560000        3.000000
# 50%             4.000000          3.000000         0.720000        4.000000
# 75%             4.000000          3.000000         0.870000        5.000000
# max             4.000000          3.000000         1.000000        7.000000
#
#         average_montly_hours  time_spend_company  Work_accident  left_Company  \
# count           14999.000000        14999.000000   14999.000000  14999.000000
# unique                   NaN                 NaN            NaN           NaN
# top                      NaN                 NaN            NaN           NaN
# freq                     NaN                 NaN            NaN           NaN
# mean              201.050337            3.498233       0.144610      0.238083
# std                49.943099            1.460136       0.351719      0.425924
# min                96.000000            2.000000       0.000000      0.000000
# 25%               156.000000            3.000000       0.000000      0.000000
# 50%               200.000000            3.000000       0.000000      0.000000
# 75%               245.000000            4.000000       0.000000      0.000000
# max               310.000000           10.000000       1.000000      1.000000
#
#         CSR Factor  promotion_last_5years  sales salary Gender  LinkedIn_Hits  \
# count       1713.0           14999.000000  14999  14999  14999   14999.000000
# unique         NaN                    NaN     10      3      2            NaN
# top            NaN                    NaN  sales    low      F            NaN
# freq           NaN                    NaN   4140   7316   7596            NaN
# mean           5.0               0.021268    NaN    NaN    NaN      18.553904
# std            0.0               0.144281    NaN    NaN    NaN      18.987335
# min            5.0               0.000000    NaN    NaN    NaN       1.000000
# 25%            5.0               0.000000    NaN    NaN    NaN       5.000000
# 50%            5.0               0.000000    NaN    NaN    NaN       9.000000
# 75%            5.0               0.000000    NaN    NaN    NaN      31.000000
# max            5.0               1.000000    NaN    NaN    NaN      65.000000
#
#         Emp_Work_Status2  Emp_Work_Status_3  Emp_Work_Status_4  \
# count       14999.000000       14999.000000       14999.000000
# unique               NaN                NaN                NaN
# top                  NaN                NaN                NaN
# freq                 NaN                NaN                NaN
# mean            3.001867           3.014468           3.005800
# std             1.413788           1.417319           1.418791
# min             1.000000           1.000000           1.000000
# 25%             2.000000           2.000000           2.000000
# 50%             3.000000           3.000000           3.000000
# 75%             4.000000           4.000000           4.000000
# max             5.000000           5.000000           5.000000
#
#         Emp_Work_Status_5  Emp_Identity      Emp_Role  Emp_Position  \
# count        14999.000000  14999.000000  14999.000000  14999.000000
# unique                NaN           NaN           NaN           NaN
# top                   NaN           NaN           NaN           NaN
# freq                  NaN           NaN           NaN           NaN
# mean             3.002867      2.141343      2.116274      1.998400
# std              1.413008      1.023277      1.010454      0.865389
# min              1.000000      1.000000      1.000000      1.000000
# 25%              2.000000      1.000000      1.000000      1.000000
# 50%              3.000000      2.000000      2.000000      2.000000
# 75%              4.000000      3.000000      3.000000      2.000000
# max              5.000000      5.000000      5.000000      5.000000
#
#            Emp_Title  Women_Leave    Men_Leave  Emp_Competitive_1  \
# count   14999.000000  7596.000000  4865.000000       14999.000000
# unique           NaN          NaN          NaN                NaN
# top              NaN          NaN          NaN                NaN
# freq             NaN          NaN          NaN                NaN
# mean        1.990066     0.707741     0.908530           2.156010
# std         0.856232     0.454831     0.288306           1.032378
# min         1.000000     0.000000     0.000000           1.000000
# 25%         1.000000     0.000000     1.000000           1.000000
# 50%         2.000000     1.000000     1.000000           2.000000
# 75%         2.000000     1.000000     1.000000           3.000000
# max         5.000000     1.000000     1.000000           5.000000
#
#         Emp_Competitive_2  Emp_Competitive_3  Emp_Competitive_4  \
# count        14999.000000       14999.000000       14999.000000
# unique                NaN                NaN                NaN
# top                   NaN                NaN                NaN
# freq                  NaN                NaN                NaN
# mean             2.987199           2.144010           2.999067
# std              1.416793           1.030439           1.406128
# min              1.000000           1.000000           1.000000
# 25%              2.000000           1.000000           2.000000
# 50%              3.000000           2.000000           3.000000
# 75%              4.000000           3.000000           4.000000
# max              5.000000           5.000000           5.000000
#
#         Emp_Competitive_5  Emp_Collaborative_1  Emp_Collaborative_2  \
# count        14999.000000         14999.000000         14999.000000
# unique                NaN                  NaN                  NaN
# top                   NaN                  NaN                  NaN
# freq                  NaN                  NaN                  NaN
# mean             2.987066             2.979532             1.676245
# std              1.412314             1.412579             0.865230
# min              1.000000             1.000000             1.000000
# 25%              2.000000             2.000000             1.000000
# 50%              3.000000             3.000000             2.000000
# 75%              4.000000             4.000000             2.000000
# max              5.000000             5.000000             5.000000
#
#         Emp_Collaborative_3  Emp_Collaborative_4  Emp_Collaborative_5  \
# count          14999.000000         14999.000000         14999.000000
# unique                  NaN                  NaN                  NaN
# top                     NaN                  NaN                  NaN
# freq                    NaN                  NaN                  NaN
# mean               2.998533             3.005200             3.016934
# std                1.410058             1.410191             1.412225
# min                1.000000             1.000000             1.000000
# 25%                2.000000             2.000000             2.000000
# 50%                3.000000             3.000000             3.000000
# 75%                4.000000             4.000000             4.000000
# max                5.000000             5.000000             5.000000
#
#         Sensor_StepCount  Sensor_Heartbeat(Average/Min)  \
# count       14999.000000                   14999.000000
# unique               NaN                            NaN
# top                  NaN                            NaN
# freq                 NaN                            NaN
# mean         3406.693246                      77.967198
# std          1755.742272                       7.252848
# min          1000.000000                      60.000000
# 25%          1704.500000                      75.000000
# 50%          3376.000000                      78.000000
# 75%          4893.000000                      85.000000
# max          8500.000000                      90.000000
#
#         Sensor_Proximity(1-highest/10-lowest)
# count                            14999.000000
# unique                                    NaN
# top                                       NaN
# freq                                      NaN
# mean                                 6.399360
# std                                  2.588091
# min                                  1.000000
# 25%                                  5.000000
# 50%                                  7.000000
# 75%                                  8.000000
# max                                 10.000000

# %% [markdown]
# * The dataset consists of details of employees from 9 different countries working in 6 departments performing various roles.
#
# * There is about 50% chance that an employee will relocate.
#
# * Almost 61% of the work is done remotely by the employees.
#
# * Each employee has completed atleast 2 projects and a maximum of 7 projects.
#
# * Each employee works for minimum of 96 hours and a maximum of 310 hours on an average monthly.
#
# * Almost 24% of the employees already left the organization.
#
# * Only 2% of the employees got promotion in the last 5 years and most of the employees get low salary.
#
# * Majority of the employees are females.

# %%
plt.figure(figsize=(8,5))
sns.countplot(data['GEO'])
plt.title('Countplot of Geographical locations')
plt.tight_layout()
plt.show()

# %% [markdown]
# *Compared to other countries, more employees are from UK and the least number of employees are from Australia. But there isn't a comparable difference in the number of employees from different countries.

# %%
plt.figure(figsize=(8,5))
sns.countplot(data['Department'])
plt.title('Countplot of Departments')
plt.tight_layout()
plt.show()

# %% [markdown]
# *The number of employees from different departments are almost equal.

# %%
plt.figure(figsize=(8,5))
ax=sns.countplot(data['Role'])
for p in ax.patches:
   ax.annotate('{:.1f}'.format(p.get_height()), (p.get_x()+0.25, p.get_height()+0.01))
plt.title('Countplot of Roles')
plt.tight_layout()
plt.show()

# %% [markdown]
# *The organization has a total of 110 VP's, 330 Senior Directors, and 660 Directors.

# %%
data[['average_montly_hours','last_evaluation']].corr()
# Out:
#                       average_montly_hours  last_evaluation
# average_montly_hours              1.000000         0.339742
# last_evaluation                   0.339742         1.000000

# %% [markdown]
# *There is a low positive correlation between average monthly hours and last evaluation.

# %%
data[['average_montly_hours','number_project']].corr()
# Out:
#                       average_montly_hours  number_project
# average_montly_hours              1.000000        0.417211
# number_project                    0.417211        1.000000

# %% [markdown]
# *There is a low positive correlation between average monthly hours and number of projects.

# %%
data[['LinkedIn_Hits','Percent_Remote']].corr()
# Out:
#                 LinkedIn_Hits  Percent_Remote
# LinkedIn_Hits        1.000000       -0.713644
# Percent_Remote      -0.713644        1.000000

# %% [markdown]
# *LinkedIn hits and Percent remote columns have high negative correlation.

# %%
data.groupby('Gender')['average_montly_hours'].mean()
# Out:
# Gender
# F    200.216035
# M    201.906389
# Name: average_montly_hours, dtype: float64

# %% [markdown]
# *Both male and female employees spend almost same amount of time for work monthly.

# %%
data.groupby('Gender')['Work_accident'].sum()
# Out:
# Gender
# F    1124
# M    1045
# Name: Work_accident, dtype: int64

# %% [markdown]
# *Females have had more work accidents when compared to males.

# %%
data.groupby('Gender')['left_Company'].sum()
# Out:
# Gender
# F    1840
# M    1731
# Name: left_Company, dtype: int64

# %% [markdown]
# *More females have left the organization than males.

# %%
plt.figure(figsize=(5,4))
sns.violinplot(y=data['LinkedIn_Hits'])
plt.title('Violinplot of LinkedIn hits')
plt.tight_layout()
plt.show()

# %% [markdown]
# *more frequent linkedin hits are in between 0 and 10.

# %%
sns.countplot(data['salary'], hue=data['Gender'])
plt.title('Countplot of salaries Gender wise')
plt.tight_layout()
plt.show()

# %% [markdown]
# *Number of males and females in each salary level are almost equal.
#
# *Most of the employees receive low salary.
#
# *only few employees enjoy high salary.

# %%
plt.figure(figsize=(7,5))
sns.countplot(data['Department'], hue=data['left_Company'])
plt.title('Employee Attrition w.r.t Departments')
plt.xlabel('Department', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.legend(['No','Yes'], title = "Attrition",loc="upper right")
plt.tight_layout()
plt.show()

# %% [markdown]
# *Almost same number of employees have left from each department.

# %%
plt.figure(figsize=(7,5))
sns.countplot(data['GEO'], hue=data['Will_Relocate'])
plt.title('Whether Employee will relocate w.r.t Geographic locations')
plt.legend(['No','Yes'],title='will relocate', loc="upper left")
plt.tight_layout()
plt.show()

# %% [markdown]
# *When we compare all of the geographic locations, we can see that there is not much difference between the number of employees willing to relocate and not.

# %%
plt.figure(figsize=(7,6))
sns.countplot(data['Role'], hue=data['left_Company'])
plt.title('Employee Attrition w.r.t Roles')
plt.legend(['No','Yes'],title='left company', loc="upper right")
plt.xticks(rotation=90, fontsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# *Most of the employees who have left the company are from Level 2-4 role.
#
# *Number of employees who left the organization increased with total number of employees in each role.

# %%
sns.countplot(data['salary'], hue=data['left_Company'])
plt.title('Employee Attrition w.r.t Salary')
plt.legend(['No','Yes'],title='left company', loc="upper right")
plt.xticks(rotation=90, fontsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# *Employees with low salaries have left the organization in more numbers.

# %%
plt.figure(figsize=(8,5))
sns.countplot(data['time_spend_company'], hue=data['left_Company'])
plt.title("Employee's Time spent in company w.r.t Attrition")
plt.legend(['No','Yes'],title='Attrition', loc="upper right")
plt.tight_layout()
plt.show()

# %% [markdown]
# Employee's who left spent almost 2-6 years in the company.

# %%
sns.kdeplot(data['number_project'],fill=True)
plt.title('KDE plot of number of projects')
plt.tight_layout()
plt.show()

# %% [markdown]
# *Each employee has completed atleast 2 projects and a maximum of 7 projects.
#
# *Most of the employees have completed 3-5 projects.

# %%
sns.kdeplot(data['time_spend_company'],fill=True)
plt.title('KDE plot of number of years spend in company')
plt.tight_layout()
plt.show()

# %% [markdown]
# *Most of the employees have spend 2-4 years in the organization.

# %%
#attrition w.r.t average monthly hrs 
plt.figure(figsize=(8,6))
sns.histplot(x='average_montly_hours', hue='left_Company', data=data, kde=True)
plt.title('Attrition w.r.t  Average monthly hours')
plt.legend(['Yes','No'],title='Attrition', loc="upper left")
plt.show()

# %% [markdown]
# *All the employees who have worked for nearly 300 hours on a monthly average left the organization.
#
# *Employees who have worked for minimum hours on a monthly average are continuing in the organization.

# %%
data.columns
# Out:
# Index(['ID', 'Name', 'Department', 'GEO', 'Role', 'Rising_Star',
#        'Will_Relocate', 'Critical', 'Trending Perf', 'Talent_Level',
#        'Validated_Talent_Level', 'Percent_Remote', 'EMP_Sat_OnPrem_1',
#        'EMP_Sat_OnPrem_2', 'EMP_Sat_OnPrem_3', 'EMP_Sat_OnPrem_4',
#        'EMP_Sat_OnPrem_5', 'EMP_Sat_Remote_1', 'EMP_Sat_Remote_2',
#        'EMP_Sat_Remote_3', 'EMP_Sat_Remote_4', 'EMP_Sat_Remote_5',
#        'EMP_Engagement_1', 'EMP_Engagement_2', 'EMP_Engagement_3',
#        'EMP_Engagement_4', 'EMP_Engagement_5', 'last_evaluation',
#        'number_project', 'average_montly_hours', 'time_spend_company',
#        'Work_accident', 'left_Company', 'CSR Factor', 'promotion_last_5years',
#        'sales', 'salary', 'Gender', 'LinkedIn_Hits', 'Emp_Work_Status2',
#        'Emp_Work_Status_3', 'Emp_Work_Status_4', 'Emp_Work_Status_5',
#        'Emp_Identity', 'Emp_Role', 'Emp_Position', 'Emp_Title', 'Women_Leave',
#        'Men_Leave', 'Emp_Competitive_1', 'Emp_Competitive_2',
#        'Emp_Competitive_3', 'Emp_Competitive_4', 'Emp_Competitive_5',
#        'Emp_Collaborative_1', 'Emp_Collaborative_2', 'Emp_Collaborative_3',
#        'Emp_Collaborative_4', 'Emp_Collaborative_5', 'Sensor_StepCount',
#        'Sensor_Heartbeat(Average/Min)',
#        'Sensor_Proximity(1-highest/10-lowest)'],
#       dtype='object')

# %%
plt.figure(figsize=(10,10))
dt_htmap=data[['Will_Relocate','last_evaluation',
       'number_project', 'average_montly_hours', 'time_spend_company',
       'Work_accident', 'left_Company','promotion_last_5years','Emp_Identity','Percent_Remote','LinkedIn_Hits']]
sns.heatmap(dt_htmap.corr(), annot=True, cmap='YlGnBu')

# %% [markdown]
# * There is a strong positive correlation between the columns   'Percent_Remote' and 'last_evaluation'.
# * There is a high negative correlation between the columns 'Percent_Remote' and 'LinkedIn_Hits'.
# * There is a high negative correlation between the columns 'last_evaluation' and 'LinkedIn_Hits'.

# %% [markdown]
# # 2.Data pre-processing-:

# %% [markdown]
# ### Handling missing values-:

# %%
pd.set_option('display.max_rows', 500)

# %%
data.isna().sum()
# Out:
# ID                                           0
# Name                                         2
# Department                                   0
# GEO                                          0
# Role                                         0
# Rising_Star                              14978
# Will_Relocate                                0
# Critical                                 14519
# Trending Perf                                0
# Talent_Level                                 0
# Validated_Talent_Level                       0
# Percent_Remote                               0
# EMP_Sat_OnPrem_1                           128
# EMP_Sat_OnPrem_2                           128
# EMP_Sat_OnPrem_3                           128
# EMP_Sat_OnPrem_4                           128
# EMP_Sat_OnPrem_5                           128
# EMP_Sat_Remote_1                             0
# EMP_Sat_Remote_2                             0
# EMP_Sat_Remote_3                             0
# EMP_Sat_Remote_4                             0
# EMP_Sat_Remote_5                             0
# EMP_Engagement_1                             0
# EMP_Engagement_2                             0
# EMP_Engagement_3                             0
# EMP_Engagement_4                             0
# EMP_Engagement_5                             0
# last_evaluation                              0
# number_project                               0
# average_montly_hours                         0
# time_spend_company                           0
# Work_accident                                0
# left_Company                                 0
# CSR Factor                               13286
# promotion_last_5years                        0
# sales                                        0
# salary                                       0
# Gender                                       0
# LinkedIn_Hits                                0
# Emp_Work_Status2                             0
# Emp_Work_Status_3                            0
# Emp_Work_Status_4                            0
# Emp_Work_Status_5                            0
# Emp_Identity                                 0
# Emp_Role                                     0
# Emp_Position                                 0
# Emp_Title                                    0
# Women_Leave                               7403
# Men_Leave                                10134
# Emp_Competitive_1                            0
# Emp_Competitive_2                            0
# Emp_Competitive_3                            0
# Emp_Competitive_4                            0
# Emp_Competitive_5                            0
# Emp_Collaborative_1                          0
# Emp_Collaborative_2                          0
# Emp_Collaborative_3                          0
# Emp_Collaborative_4                          0
# Emp_Collaborative_5                          0
# Sensor_StepCount                             0
# Sensor_Heartbeat(Average/Min)                0
# Sensor_Proximity(1-highest/10-lowest)        0
# dtype: int64

# %% [markdown]
# In the dataset, the columns Name, Rising star, Critical, EMP_Sat_OnPrem_1, EMP_Sat_OnPrem_2, EMP_Sat_OnPrem_3, EMP_Sat_OnPrem_4, EMP_Sat_OnPrem_5, CSR Factor, Women_Leave, Men_Leave have missing values.

# %% [markdown]
# First we will handle missing values in the columns EMP_Sat_OnPrem_1,EMP_Sat_OnPrem_2,EMP_Sat_OnPrem_3,EMP_Sat_OnPrem_4 and EMP_Sat_OnPrem_5.

# %%
#check for skewness
freqgraph=data[['EMP_Sat_OnPrem_1','EMP_Sat_OnPrem_2','EMP_Sat_OnPrem_3','EMP_Sat_OnPrem_4','EMP_Sat_OnPrem_5']]
freqgraph.hist(figsize=(20,15))
plt.show()

# %% [markdown]
# Since we observed skewness in most of these columns, we fill the missing values in these columns with their respective modes.

# %%
for i in data[['EMP_Sat_OnPrem_1','EMP_Sat_OnPrem_2','EMP_Sat_OnPrem_3','EMP_Sat_OnPrem_4','EMP_Sat_OnPrem_5']]:
  data[i]=data[i].fillna(data[i].mode()[0])

# %% [markdown]
# There are two missing values in the column 'Name'. Since the data in this column is not much relevant for our study, we let it stay as it is.

# %% [markdown]
# The columns 'Rising star', 'Critical', 'CSR factor' have more than 80% missing values. Also 'Women_Leave','Men_Leave' columns have more than 48% missing values we choose not to fill these columns and drop them eventually.

# %%
data.isna().sum()
# Out:
# ID                                           0
# Name                                         2
# Department                                   0
# GEO                                          0
# Role                                         0
# Rising_Star                              14978
# Will_Relocate                                0
# Critical                                 14519
# Trending Perf                                0
# Talent_Level                                 0
# Validated_Talent_Level                       0
# Percent_Remote                               0
# EMP_Sat_OnPrem_1                             0
# EMP_Sat_OnPrem_2                             0
# EMP_Sat_OnPrem_3                             0
# EMP_Sat_OnPrem_4                             0
# EMP_Sat_OnPrem_5                             0
# EMP_Sat_Remote_1                             0
# EMP_Sat_Remote_2                             0
# EMP_Sat_Remote_3                             0
# EMP_Sat_Remote_4                             0
# EMP_Sat_Remote_5                             0
# EMP_Engagement_1                             0
# EMP_Engagement_2                             0
# EMP_Engagement_3                             0
# EMP_Engagement_4                             0
# EMP_Engagement_5                             0
# last_evaluation                              0
# number_project                               0
# average_montly_hours                         0
# time_spend_company                           0
# Work_accident                                0
# left_Company                                 0
# CSR Factor                               13286
# promotion_last_5years                        0
# sales                                        0
# salary                                       0
# Gender                                       0
# LinkedIn_Hits                                0
# Emp_Work_Status2                             0
# Emp_Work_Status_3                            0
# Emp_Work_Status_4                            0
# Emp_Work_Status_5                            0
# Emp_Identity                                 0
# Emp_Role                                     0
# Emp_Position                                 0
# Emp_Title                                    0
# Women_Leave                               7403
# Men_Leave                                10134
# Emp_Competitive_1                            0
# Emp_Competitive_2                            0
# Emp_Competitive_3                            0
# Emp_Competitive_4                            0
# Emp_Competitive_5                            0
# Emp_Collaborative_1                          0
# Emp_Collaborative_2                          0
# Emp_Collaborative_3                          0
# Emp_Collaborative_4                          0
# Emp_Collaborative_5                          0
# Sensor_StepCount                             0
# Sensor_Heartbeat(Average/Min)                0
# Sensor_Proximity(1-highest/10-lowest)        0
# dtype: int64

# %% [markdown]
# ### Handling Outliers-:

# %%
data1=data.select_dtypes(include=['int','float'])
data1.dtypes
# Out:
# ID                                         int64
# Rising_Star                              float64
# Will_Relocate                              int64
# Critical                                 float64
# Trending Perf                              int64
# Talent_Level                               int64
# Validated_Talent_Level                     int64
# Percent_Remote                           float64
# EMP_Sat_OnPrem_1                         float64
# EMP_Sat_OnPrem_2                         float64
# EMP_Sat_OnPrem_3                         float64
# EMP_Sat_OnPrem_4                         float64
# EMP_Sat_OnPrem_5                         float64
# EMP_Sat_Remote_1                           int64
# EMP_Sat_Remote_2                           int64
# EMP_Sat_Remote_3                           int64
# EMP_Sat_Remote_4                           int64
# EMP_Sat_Remote_5                           int64
# EMP_Engagement_1                           int64
# EMP_Engagement_2                           int64
# EMP_Engagement_3                           int64
# EMP_Engagement_4                           int64
# EMP_Engagement_5                           int64
# last_evaluation                          float64
# number_project                             int64
# average_montly_hours                       int64
# time_spend_company                         int64
# Work_accident                              int64
# left_Company                               int64
# CSR Factor                               float64
# promotion_last_5years                      int64
# LinkedIn_Hits                              int64
# Emp_Work_Status2                           int64
# Emp_Work_Status_3                          int64
# Emp_Work_Status_4                          int64
# Emp_Work_Status_5                          int64
# Emp_Identity                               int64
# Emp_Role                                   int64
# Emp_Position                               int64
# Emp_Title                                  int64
# Women_Leave                              float64
# Men_Leave                                float64
# Emp_Competitive_1                          int64
# Emp_Competitive_2                          int64
# Emp_Competitive_3                          int64
# Emp_Competitive_4                          int64
# Emp_Competitive_5                          int64
# Emp_Collaborative_1                        int64
# Emp_Collaborative_2                        int64
# Emp_Collaborative_3                        int64
# Emp_Collaborative_4                        int64
# Emp_Collaborative_5                        int64
# Sensor_StepCount                           int64
# Sensor_Heartbeat(Average/Min)              int64
# Sensor_Proximity(1-highest/10-lowest)      int64
# dtype: object

# %%
#check for outliers
plt.figure(figsize=(15,50))
for i,feature in enumerate(data1.columns):
    plt.subplot(20,3,i+1)
    plt.boxplot(data1[feature])
    plt.title(feature)
    plt.tight_layout()
plt.show()

# %%
data['time_spend_company'].value_counts()
# Out:
# 3     6443
# 2     3244
# 4     2557
# 5     1473
# 6      718
# 10     214
# 7      188
# 8      162
# Name: time_spend_company, dtype: int64

# %%
data['Emp_Position'].value_counts()
# Out:
# 2    7025
# 1    4518
# 3    2490
# 4     894
# 5      72
# Name: Emp_Position, dtype: int64

# %%
data['Emp_Title'].value_counts()
# Out:
# 2    6971
# 1    4570
# 3    2535
# 4     883
# 5      40
# Name: Emp_Title, dtype: int64

# %%
data['Emp_Collaborative_2'].value_counts()
# Out:
# 1    7072
# 2    7035
# 4     460
# 5     432
# Name: Emp_Collaborative_2, dtype: int64

# %% [markdown]
# We detected outliers in certain columns, but when we checked for its unique values we understood that these values cannot be treated as outliers.

# %% [markdown]
# ### Feature Engineering-:

# %%
data['EMP_Sat_OnPrem']=data[['EMP_Sat_OnPrem_1', 'EMP_Sat_OnPrem_2', 'EMP_Sat_OnPrem_3', 'EMP_Sat_OnPrem_4', 'EMP_Sat_OnPrem_5']].mean(axis=1)

# %% [markdown]
# We created a new column 'EMP_Sat_OnPrem' by taking the mean of the 5 columns having data of survey that was sent to employees. It indicates the employee's satisfaction of work on the corporation’s physical work locations. Scale (1-10).

# %%
data['EMP_Sat_Remote']=data[['EMP_Sat_Remote_1', 'EMP_Sat_Remote_2', 'EMP_Sat_Remote_3', 'EMP_Sat_Remote_4', 'EMP_Sat_Remote_5']].mean(axis=1)

# %% [markdown]
# We created a new column 'EMP_Sat_Remote' by taking the mean of the 5 columns having data of survey that was sent to employees. It indicates the employee's satisfaction of work away from the corporation’s physical work locations. Scale (1-10)

# %%
data['EMP_Engagement']=data[['EMP_Engagement_1', 'EMP_Engagement_2', 'EMP_Engagement_3','EMP_Engagement_4', 'EMP_Engagement_5']].mean(axis=1)

# %% [markdown]
# We created a new column 'EMP_Engagement' by taking the mean of the 5 columns having data of survey that was sent to employees. Engagement represents the employee's feeling about how they feel about being engaged in company activities. Scale(1-5)

# %%
data['Emp_Work_Status']=data[['Emp_Work_Status2','Emp_Work_Status_3', 'Emp_Work_Status_4', 'Emp_Work_Status_5']].mean(axis=1)

# %% [markdown]
# We created a new column 'Emp_Work_Status' by taking the mean of the 4 columns having data of survey that was sent to employees. Status represents how strongly employee feels about their status level in the organization. Scale (1-10)

# %%
data['Emp_Competitive']=data[['Emp_Competitive_1', 'Emp_Competitive_2', 'Emp_Competitive_3', 'Emp_Competitive_4', 'Emp_Competitive_5']].mean(axis=1)

# %% [markdown]
# We created a new column 'Emp_Competitive' by taking the mean of the 5 columns having data of survey that was sent to employees. It shows how the employee feels about the competitive nature of work in the organization. Scale (1-10)

# %%
data['Emp_Collaborative']=data[['Emp_Collaborative_1', 'Emp_Collaborative_2', 'Emp_Collaborative_3','Emp_Collaborative_4', 'Emp_Collaborative_5']].mean(axis=1)

# %% [markdown]
# We created a new column 'Emp_Collaborative' by taking the mean of the 5 columns having data of survey that was sent to employees. It indicates how employee feels about the collaborative nature of work in the organization.Scale (1-10)

# %% [markdown]
# ### Encoding-:

# %%
#label encoding
from sklearn.preprocessing import LabelEncoder
label_en=LabelEncoder()
for i in data[['Department', 'GEO', 'Role', 'sales', 'salary', 'Gender']]:
    data[i]=label_en.fit_transform(data[i])

# %% [markdown]
# We have encoded our categorical variables required for modelling using label encoding.

# %% [markdown]
# ### Feature Reduction-:

# %%
data.drop(['ID', 'Name','Sensor_StepCount','Sensor_Heartbeat(Average/Min)','Sensor_Proximity(1-highest/10-lowest)'], axis=1, inplace=True)

# %% [markdown]
# We drop these columns since they are irrelevant while modelling.

# %%
data.drop(['Rising_Star','Critical','CSR Factor','Women_Leave','Men_Leave'], axis=1, inplace=True)

# %% [markdown]
# We drop these columns since they have huge amount of missing values.

# %%
data.drop(['EMP_Sat_OnPrem_1',
       'EMP_Sat_OnPrem_2', 'EMP_Sat_OnPrem_3', 'EMP_Sat_OnPrem_4',
       'EMP_Sat_OnPrem_5', 'EMP_Sat_Remote_1', 'EMP_Sat_Remote_2',
       'EMP_Sat_Remote_3', 'EMP_Sat_Remote_4', 'EMP_Sat_Remote_5',
       'EMP_Engagement_1', 'EMP_Engagement_2', 'EMP_Engagement_3',
       'EMP_Engagement_4', 'EMP_Engagement_5','Emp_Work_Status2',
       'Emp_Work_Status_3', 'Emp_Work_Status_4', 'Emp_Work_Status_5','Emp_Competitive_1', 'Emp_Competitive_2',
       'Emp_Competitive_3', 'Emp_Competitive_4', 'Emp_Competitive_5','Emp_Collaborative_1', 'Emp_Collaborative_2',
        'Emp_Collaborative_3','Emp_Collaborative_4', 'Emp_Collaborative_5'], axis=1, inplace=True)

# %% [markdown]
# We drop these columns because we have generated new columns using the data in these columns.

# %%
data.shape
# Out:
# (14999, 29)

# %%
plt.figure(figsize=(20,20))
sns.heatmap(data.corr(),annot=True, cmap='YlGnBu')
plt.tight_layout()

# %%
data.drop(['Trending Perf', 'Talent_Level', 'Validated_Talent_Level','last_evaluation'], axis=1, inplace=True)

# %% [markdown]
# We drop the columns 'Trending Perf', 'Talent_Level', 'Validated_Talent_Level' since these columns have only one value. So keeping them will not have any effect on our model.
# The columns 'last evaluation' and 'percent_remote' have strong positive correlation. When we checked the correlation of these columns with our target variable 'left_company', we observed that 'percent_remote' have comparatively larger correlation with the target variable. So we kept the 'percent_remote' column and dropped 'last evaluation' column.

# %%
data.columns
# Out:
# Index(['Department', 'GEO', 'Role', 'Will_Relocate', 'Percent_Remote',
#        'number_project', 'average_montly_hours', 'time_spend_company',
#        'Work_accident', 'left_Company', 'promotion_last_5years', 'sales',
#        'salary', 'Gender', 'LinkedIn_Hits', 'Emp_Identity', 'Emp_Role',
#        'Emp_Position', 'Emp_Title', 'EMP_Sat_OnPrem', 'EMP_Sat_Remote',
#        'EMP_Engagement', 'Emp_Work_Status', 'Emp_Competitive',
#        'Emp_Collaborative'],
#       dtype='object')

# %%
data.shape
# Out:
# (14999, 25)

# %% [markdown]
# # **Standardization-:**

# %% [markdown]
# ## Here we are going to do two models.
#
# 1)- Classification(with target variable- left_Company)
#
# 2)- Regression (with target variable- time_spend_company)

# %% [markdown]
# In the classification model, we predict whether an employee will leave or remain in the organization. In case the employee leaves, then we will predict within how much time he/she will leave using regression model.

# %% [markdown]
# ## Classification-:

# %%
x1=data.drop('left_Company', axis=1)
y=data['left_Company']

# %%
#Standard scaling
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x = sc.fit_transform(x1)

#converting it into a dataframe
x = pd.DataFrame(x, columns=x1.columns)

# %%
x.head()
# Out:
#    Department       GEO      Role  Will_Relocate  Percent_Remote  \
# 0    0.292879  1.545591  3.092578      -0.999667       -1.121168
# 1    0.878441  1.156071  1.468035      -0.999667       -1.121168
# 2   -1.463808 -0.402012  1.468035      -0.999667       -1.121168
# 3   -0.878246 -1.181054  1.468035      -0.999667       -1.121168
# 4   -0.292684  0.377029 -1.781051      -0.999667       -1.121168
#
#    number_project  average_montly_hours  time_spend_company  Work_accident  \
# 0       -0.651538             -0.661782           -0.341235       2.432112
# 1        0.971113             -0.841993           -1.026126      -0.411165
# 2       -1.462863              1.620892           -0.341235      -0.411165
# 3        0.159788              1.540798            0.343655       2.432112
# 4        1.782438              1.100282            1.028546      -0.411165
#
#    promotion_last_5years     sales    salary    Gender  LinkedIn_Hits  \
# 0              -0.147412  0.393725 -0.554955  1.012951      -0.713863
# 1              -0.147412 -1.349230 -0.554955 -0.987214       2.077564
# 2              -0.147412  0.045134  1.043004 -0.987214       1.234869
# 3              -0.147412  0.045134 -2.152913  1.012951       0.971527
# 4              -0.147412  0.393725 -0.554955 -0.987214      -0.661195
#
#    Emp_Identity  Emp_Role  Emp_Position  Emp_Title  EMP_Sat_OnPrem  \
# 0     -1.115417 -1.104762      0.001849  -1.156345        0.575242
# 1     -0.138132 -1.104762      0.001849  -1.156345        0.575242
# 2     -1.115417 -1.104762      0.001849   0.011602        0.575242
# 3     -0.138132 -1.104762      0.001849  -1.156345        0.575242
# 4     -1.115417 -1.104762      0.001849  -1.156345        0.575242
#
#    EMP_Sat_Remote  EMP_Engagement  Emp_Work_Status  Emp_Competitive  \
# 0       -1.459808        0.558997        -1.065125        -0.416489
# 1       -1.459808        0.558997         0.343304        -1.070651
# 2       -1.459808        0.558997        -0.713018         0.237673
# 3       -1.459808        0.558997         0.343304        -1.070651
# 4       -1.459808        0.558997         2.103841         0.237673
#
#    Emp_Collaborative
# 0          -0.570128
# 1           0.790199
# 2           0.790199
# 3          -0.570128
# 4           1.130280

# %% [markdown]
# ## Regression-:

# %% [markdown]
# Here we are considering only the data having left_company value as 1. ie, the data of employees who left the organization.

# %%
df1 = data[data['left_Company']==1]

# %%
p1=df1.drop('time_spend_company', axis=1)
q=df1['time_spend_company']

# %%
#Standard scaling
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
p = sc.fit_transform(p1)

#converting it into a dataframe
p = pd.DataFrame(p, columns=p1.columns)

# %%
p.head()
# Out:
#    Department       GEO      Role  Will_Relocate  Percent_Remote  \
# 0    0.880345  0.756365  0.674707      -0.983612       -1.074459
# 1   -1.465271  1.147019  0.674707       1.016661       -1.074459
# 2   -0.878867  1.537673  0.674707      -0.983612       -1.074459
# 3   -0.292463  0.365712  0.674707      -0.983612       -1.074459
# 4    1.466749  1.147019  0.674707      -0.983612       -1.074459
#
#    number_project  average_montly_hours  Work_accident  left_Company  \
# 0       -1.020679             -1.232456      -0.222883           0.0
# 1       -1.020679             -0.921969      -0.222883           0.0
# 2       -1.020679             -1.232456      -0.222883           0.0
# 3       -1.020679             -1.183432      -0.222883           0.0
# 4       -1.020679             -0.840262      -0.222883           0.0
#
#    promotion_last_5years     sales    salary    Gender  LinkedIn_Hits  \
# 0              -0.073138  0.343775 -0.662925  1.031004       1.146103
# 1              -0.073138  0.700124 -0.662925  1.031004       1.357624
# 2              -0.073138 -0.368922 -0.662925  1.031004       1.780668
# 3              -0.073138 -0.368922 -0.662925  1.031004      -0.493190
# 4              -0.073138  0.343775  1.253921 -0.969928       1.780668
#
#    Emp_Identity  Emp_Role  Emp_Position  Emp_Title  EMP_Sat_OnPrem  \
# 0      0.898827  0.987982     -0.994136  -0.998601        0.558457
# 1     -0.941604  0.987982     -0.994136  -0.998601        0.558457
# 2      0.898827 -0.948398     -0.994136  -0.998601        0.558457
# 3     -0.941604 -0.948398     -0.994136  -0.998601        0.558457
# 4     -0.941604  0.987982     -0.994136   1.001401        0.558457
#
#    EMP_Sat_Remote  EMP_Engagement  Emp_Work_Status  Emp_Competitive  \
# 0        -1.09594   -2.220446e-16        -0.724368        -0.391840
# 1        -1.09594   -2.220446e-16         1.041310        -1.144941
# 2        -1.09594   -2.220446e-16         2.100717         0.737811
# 3        -1.09594   -2.220446e-16         0.335039         1.867462
# 4        -1.09594   -2.220446e-16         0.335039         0.361261
#
#    Emp_Collaborative
# 0          -0.583618
# 1           0.774102
# 2          -1.262478
# 3          -1.262478
# 4          -1.941338

# %% [markdown]
# # **3.Predictive Modelling and Fine Tuning-:**

# %% [markdown]
# ## Classification-:

# %%
#split the dataset into train and test
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=42, test_size=0.3)

# %% [markdown]
# ### Logistic Regression-:

# %%
#logistic regression
from sklearn.linear_model import LogisticRegression
#creating an instance of the logistic regression model
logistic_model = LogisticRegression()
#training the model
logistic_model.fit(x_train,y_train)
#testing the model
y_predict = logistic_model.predict(x_test)

# %%
#check the performance of the model
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

print('Accuracy is :', accuracy_score(y_test,y_predict))
print('Precision is :', precision_score(y_test,y_predict))
print('Recall is :', recall_score(y_test,y_predict))
print('f1 Score is :', f1_score(y_test,y_predict))
# Out:
# Accuracy is : 1.0
# Precision is : 1.0
# Recall is : 1.0
# f1 Score is : 1.0

# %%
#check confusion matrix
confusion_matrix(y_test, y_predict)
# Out:
# array([[3458,    0],
#        [   0, 1042]])

# %% [markdown]
# ### KNN-:

# %%
from sklearn.neighbors import KNeighborsClassifier
#create model with varied k values
acc_values = []
#take 3 to 15 random values for k
neighbors = np.arange(3,15)
#loop to create kNN model for each k values
for k in neighbors:
    classifier = KNeighborsClassifier(n_neighbors=k, metric='minkowski')
    classifier.fit(x_train, y_train)
    y_predict = classifier.predict(x_test)
    acc = accuracy_score(y_test, y_predict)
    acc_values.append(acc)

# %%
plt.plot(neighbors, acc_values, 'o-')
plt.xlabel('k-values')
plt.ylabel('Accuracy')
plt.show()

# %% [markdown]
# We will take k value as 5.

# %%
#replace k as 5
classifier = KNeighborsClassifier(n_neighbors=5, metric='minkowski')
classifier.fit(x_train, y_train)
y_predict = classifier.predict(x_test)

# %%
#check the performance of the model
print('Accuracy is :', accuracy_score(y_test,y_predict))
print('Precision is :', precision_score(y_test,y_predict))
print('Recall is :', recall_score(y_test,y_predict))
print('f1 Score is :', f1_score(y_test,y_predict))
# Out:
# Accuracy is : 0.9968888888888889
# Precision is : 1.0
# Recall is : 0.9865642994241842
# f1 Score is : 0.9932367149758454

# %%
#check confusion matrix
confusion_matrix(y_test, y_predict)
# Out:
# array([[3458,    0],
#        [  14, 1028]])

# %% [markdown]
# Here there are 14 misclassifications.

# %% [markdown]
# ### SVM-:

# %% [markdown]
# Linear SVM-:

# %%
#import library
from sklearn.svm import SVC
#create an instance of the model
svm_linear = SVC(kernel='linear')
svm_linear.fit(x_train, y_train)
y_predict = svm_linear.predict(x_test)

# %%
#check the performance of the model
print('Accuracy is :', accuracy_score(y_test,y_predict))
print('Precision is :', precision_score(y_test,y_predict))
print('Recall is :', recall_score(y_test,y_predict))
print('f1 Score is :', f1_score(y_test,y_predict))
# Out:
# Accuracy is : 1.0
# Precision is : 1.0
# Recall is : 1.0
# f1 Score is : 1.0

# %% [markdown]
# Radial Basis Function SVM-:

# %%
#import library
from sklearn.svm import SVC
#create an instance of the model
svm_radial = SVC(kernel='rbf')
svm_radial.fit(x_train, y_train)
y_predict = svm_radial.predict(x_test)

# %%
#check the performance of the model
print('Accuracy is :', accuracy_score(y_test,y_predict))
print('Precision is :', precision_score(y_test,y_predict))
print('Recall is :', recall_score(y_test,y_predict))
print('f1 Score is :', f1_score(y_test,y_predict))
# Out:
# Accuracy is : 0.9997777777777778
# Precision is : 1.0
# Recall is : 0.9990403071017274
# f1 Score is : 0.99951992318771

# %%
#check confusion matrix
confusion_matrix(y_test, y_predict)
# Out:
# array([[3458,    0],
#        [   1, 1041]])

# %% [markdown]
# There is only one misclassification.

# %% [markdown]
# ### Desicion Tree Classifier-:

# %%
#import library
from sklearn.tree import DecisionTreeClassifier
#create an instance of the model
dt_model = DecisionTreeClassifier()
dt_model.fit(x_train, y_train)
y_predict = dt_model.predict(x_test)

# %%
#check the performance of the model
print('Accuracy is :', accuracy_score(y_test,y_predict))
print('Precision is :', precision_score(y_test,y_predict))
print('Recall is :', recall_score(y_test,y_predict))
print('f1 Score is :', f1_score(y_test,y_predict))
# Out:
# Accuracy is : 1.0
# Precision is : 1.0
# Recall is : 1.0
# f1 Score is : 1.0

# %% [markdown]
# ### Random Forest Classifier-:

# %%
#import libraries 
from sklearn.ensemble import RandomForestClassifier
#create the instance of the model
rf=RandomForestClassifier()
#train the data
rf.fit(x_train,y_train)
#predict x_test
y_predict=rf.predict(x_test)

# %%
#check the performance of the model
print('Accuracy is :', accuracy_score(y_test,y_predict))
print('Precision is :', precision_score(y_test,y_predict))
print('Recall is :', recall_score(y_test,y_predict))
print('f1 Score is :', f1_score(y_test,y_predict))
# Out:
# Accuracy is : 1.0
# Precision is : 1.0
# Recall is : 1.0
# f1 Score is : 1.0

# %% [markdown]
# ### Gradient Boosting Classifier-:

# %%
from sklearn.ensemble import GradientBoostingClassifier
gb=GradientBoostingClassifier()
gb.fit(x_train,y_train)
#predict the y
y_predict=gb.predict(x_test)

# %%
#check the performance of the model
print('Accuracy is :', accuracy_score(y_test,y_predict))
print('Precision is :', precision_score(y_test,y_predict))
print('Recall is :', recall_score(y_test,y_predict))
print('f1 Score is :', f1_score(y_test,y_predict))
# Out:
# Accuracy is : 1.0
# Precision is : 1.0
# Recall is : 1.0
# f1 Score is : 1.0

# %% [markdown]
# ## Regression-:

# %%
from sklearn.model_selection import train_test_split
p_train,p_test,q_train,q_test = train_test_split(p,q,random_state=42, test_size=0.2)

# %% [markdown]
# Random Forest Regressor-:

# %%
from sklearn.ensemble import RandomForestRegressor
rfr=RandomForestRegressor(random_state=32)
rfr.fit(p_train,q_train)
predictions=rfr.predict(p_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
print('MSE is :',mean_squared_error(q_test,predictions))
r2_score = rfr.score(p_test,q_test)
print('r2-score is :',r2_score)
# Out:
# MSE is : 0.16675944055944056
# r2-score is : 0.8271403877660265

# %% [markdown]
# Gradient Boosting Regressor-:

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbr=GradientBoostingRegressor(random_state=32)
gbr.fit(p_train,q_train)
predictions=gbr.predict(p_test)

# %%
print('MSE is :',mean_squared_error(q_test,predictions))
r2_score = gbr.score(p_test,q_test)
print('r2-score is :',r2_score)
# Out:
# MSE is : 0.17155153713349017
# r2-score is : 0.8221729930997995

# %% [markdown]
# XG Boosting Regressor-:

# %%
from xgboost import XGBRegressor
xgb=XGBRegressor(random_state=32)
xgb.fit(p_train,q_train)
predictions=xgb.predict(p_test)
# Out:
# [06:21:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
print('MSE is :',mean_squared_error(q_test,predictions))
r2_score = xgb.score(p_test,q_test)
print('r2-score is :',r2_score)
# Out:
# MSE is : 0.17706835354159733
# r2-score is : 0.8164543678641175

# %% [markdown]
# # Fine Tuning of hyper parameters-:

# %% [markdown]
# ## Classification-:

# %% [markdown]
# Among the models which we have created, KNN and RBF SVM have accuracy less than 100%. So we will try fine tuning the hyper parameters of these models.

# %% [markdown]
# ### KNN-:

# %%
classifier = KNeighborsClassifier(n_neighbors=5, weights='uniform',leaf_size=40, algorithm='auto', p=2, metric='minkowski', metric_params=None)
classifier.fit(x_train, y_train)
y_predict = classifier.predict(x_test)

# %%
#check the performance of the model
print('Accuracy is :', accuracy_score(y_test,y_predict))
print('Precision is :', precision_score(y_test,y_predict))
print('Recall is :', recall_score(y_test,y_predict))
print('f1 Score is :', f1_score(y_test,y_predict))
# Out:
# Accuracy is : 0.9968888888888889
# Precision is : 1.0
# Recall is : 0.9865642994241842
# f1 Score is : 0.9932367149758454

# %%
#check confusion matrix
confusion_matrix(y_test, y_predict)
# Out:
# array([[3458,    0],
#        [  14, 1028]])

# %% [markdown]
# We already got a highly accurate model. So even after fine tuning of hyper parameters we couldn't increase the performance of the model.

# %% [markdown]
# ### Radial Basis Function SVM-:

# %%
svm_radial = SVC(kernel='rbf', C=3, degree=3, gamma="auto", random_state=None)
svm_radial.fit(x_train, y_train)
y_predict = svm_radial.predict(x_test)

# %%
#check the performance of the model
print('Accuracy is :', accuracy_score(y_test,y_predict))
print('Precision is :', precision_score(y_test,y_predict))
print('Recall is :', recall_score(y_test,y_predict))
print('f1 Score is :', f1_score(y_test,y_predict))
# Out:
# Accuracy is : 1.0
# Precision is : 1.0
# Recall is : 1.0
# f1 Score is : 1.0

# %% [markdown]
# After fine tuning of hyper parameters, performance of the model increased.

# %% [markdown]
# All the models we have created are highly accurate, so we choose random forest classifier as the best fit model. Among all the available classification methods, random forests provide the highest accuracy. The random forest technique can also handle big data with numerous variables running into thousands. Also tree-based methods like Random Forests, are less impacted by outliers.

# %% [markdown]
# ## Regression-:

# %% [markdown]
# Random Forest Regressor-:

# %%
from sklearn.ensemble import RandomForestRegressor
rfr=RandomForestRegressor(n_estimators=145,random_state=32, min_samples_leaf =2)
rfr.fit(p_train,q_train)
predictions=rfr.predict(p_test)

# %%
print('MSE is :',mean_squared_error(q_test,predictions))
r2_score = rfr.score(p_test,q_test)
print('r2-score is :',r2_score)
# Out:
# MSE is : 0.16349480236712366
# r2-score is : 0.8305244486030918

# %% [markdown]
# Gradient Boosting Regressor-:

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbr=GradientBoostingRegressor(n_estimators=92,max_depth=5, min_samples_split=5, 
                                         random_state=32,
                                         warm_start=True)
gbr.fit(p_train,q_train)
predictions=gbr.predict(p_test)

# %%
print('MSE is :',mean_squared_error(q_test,predictions))
r2_score = gbr.score(p_test,q_test)
print('r2-score is :',r2_score)
# Out:
# MSE is : 0.1523495195556189
# r2-score is : 0.8420774333011183

# %% [markdown]
# XG Boosting Regressor-:

# %%
from xgboost import XGBRegressor
xgb=XGBRegressor(objective ='reg:linear', verbosity = 0, random_state=32, n_estimators=145, booster='dart')
xgb.fit(p_train,q_train)
predictions=xgb.predict(p_test)

# %%
print('MSE is :',mean_squared_error(q_test,predictions))
r2_score = xgb.score(p_test,q_test)
print('r2-score is :',r2_score)
# Out:
# MSE is : 0.17456610114074697
# r2-score is : 0.8190481543284487

# %% [markdown]
# Performance of these models improved slightly after fine tuning of hyper parameters.
#
# Among the models we have created, we found out that gradient boosting has the highest performance. Also it helps in reducing variance and bias in a machine learning ensemble. So we chose gradient boosting as the regression model.

# %% [markdown]
# ### Feature Importance-:

# %%
#check the feature importance of random forest classifier
pd.Series(rf.feature_importances_, index=x.columns).sort_values(ascending=False)*100
# Out:
# EMP_Engagement           53.226459
# number_project           10.786172
# average_montly_hours      6.257783
# time_spend_company        5.596915
# Emp_Identity              4.321356
# Emp_Role                  4.026170
# Percent_Remote            3.821340
# Emp_Title                 2.548031
# EMP_Sat_OnPrem            2.468321
# Emp_Position              2.457581
# EMP_Sat_Remote            1.450116
# LinkedIn_Hits             1.343277
# Emp_Competitive           0.484774
# Work_accident             0.335831
# salary                    0.156371
# Emp_Collaborative         0.143208
# Emp_Work_Status           0.120864
# sales                     0.116486
# GEO                       0.095154
# Role                      0.084313
# Department                0.084302
# Gender                    0.031443
# Will_Relocate             0.030280
# promotion_last_5years     0.013453
# dtype: float64

# %%
#check the feature importance of gb
pd.Series(gbr.feature_importances_, index=p.columns).sort_values(ascending=False)*100
# Out:
# number_project           74.983365
# average_montly_hours     10.834305
# Percent_Remote            2.933387
# LinkedIn_Hits             1.683936
# sales                     1.338707
# EMP_Sat_Remote            1.315002
# Emp_Competitive           1.304829
# Emp_Work_Status           0.945282
# salary                    0.820481
# GEO                       0.719007
# EMP_Sat_OnPrem            0.662497
# Emp_Collaborative         0.624094
# Department                0.623918
# Role                      0.364123
# Will_Relocate             0.305317
# Work_accident             0.120681
# Emp_Role                  0.119293
# Emp_Title                 0.113497
# Emp_Identity              0.080795
# Gender                    0.078091
# Emp_Position              0.028797
# promotion_last_5years     0.000595
# left_Company              0.000000
# EMP_Engagement            0.000000
# dtype: float64

# %%
plt.figure(figsize=(17,7))

plt.subplot(1, 2, 1)
features_list = x.columns.values
feature_importance = rf.feature_importances_
sorted_idx = np.argsort(feature_importance)
plt.barh(range(len(sorted_idx)), feature_importance[sorted_idx], align='center', color ="red")
plt.yticks(range(len(sorted_idx)), features_list[sorted_idx])
plt.xlabel('Importance')
plt.title('Feature Importance of Random Forest Classifier')

plt.subplot(1, 2, 2)
features_list = p.columns.values
feature_importance = gbr.feature_importances_
sorted_idx = np.argsort(feature_importance)
plt.barh(range(len(sorted_idx)), feature_importance[sorted_idx], align='center', color ="red")
plt.yticks(range(len(sorted_idx)), features_list[sorted_idx])
plt.xlabel('Importance')
plt.title('Feature Importance of Gradient Boosting Regressor')

plt.tight_layout()
plt.show()

# %% [markdown]
# We will drop the features having a common lower feature importance by looking into both the models.

# %% [markdown]
# ### Classification-:

# %%
#dropping features from x
x.drop(['sales','Emp_Collaborative','Emp_Work_Status','GEO','Role','Department','Will_Relocate','Gender','promotion_last_5years','EMP_Sat_OnPrem','Emp_Competitive','Work_accident','salary','Emp_Position','Emp_Title', 'Emp_Identity'], axis=1, inplace=True)

# %%
x.columns
# Out:
# Index(['Percent_Remote', 'number_project', 'average_montly_hours',
#        'time_spend_company', 'LinkedIn_Hits', 'Emp_Role', 'EMP_Sat_Remote',
#        'EMP_Engagement'],
#       dtype='object')

# %%
#again split the dataset into train and test
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=42, test_size=0.3)

# %%
#modelling
rf=RandomForestClassifier()
#train the data
rf.fit(x_train,y_train)
#predict x_test
y_pred=rf.predict(x_test)

# %%
#check the performance of the model
print('Accuracy is :', accuracy_score(y_test,y_pred))
print('Precision is :', precision_score(y_test,y_pred))
print('Recall is :', recall_score(y_test,y_pred))
print('f1 Score is :', f1_score(y_test,y_pred))
# Out:
# Accuracy is : 1.0
# Precision is : 1.0
# Recall is : 1.0
# f1 Score is : 1.0

# %% [markdown]
# ### Regression-:

# %%
#dropping features from p
p.drop(['left_Company','sales','Emp_Collaborative','Emp_Work_Status','GEO','Role','Department','Will_Relocate','Gender','promotion_last_5years','Emp_Competitive','Work_accident','salary','Emp_Position','Emp_Title', 'Emp_Identity','EMP_Sat_OnPrem'], axis=1, inplace=True)

# %%
p.columns
# Out:
# Index(['Percent_Remote', 'number_project', 'average_montly_hours',
#        'LinkedIn_Hits', 'Emp_Role', 'EMP_Sat_Remote', 'EMP_Engagement'],
#       dtype='object')

# %%
p_train,p_test,q_train,q_test = train_test_split(p,q,random_state=42, test_size=0.2)

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbr=GradientBoostingRegressor(n_estimators=91,max_depth=5, min_samples_split=5, 
                                         random_state=32)
gbr.fit(p_train,q_train)
predictions=gbr.predict(p_test)

# %%
print('MSE is :',mean_squared_error(q_test,predictions))
r2_score = gbr.score(p_test,q_test)
print('r2-score is :',r2_score)
# Out:
# MSE is : 0.16473397561616868
# r2-score is : 0.8292399455692484
